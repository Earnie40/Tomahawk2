# %% [markdown]
# # Qwen2.5-Coder:32B Setup for Google Colab
# This notebook sets up the most advanced model we discussed: **qwen2.5-coder:32b**

# %% [markdown]
# ## Step 1: Check GPU Availability

# %%
# !nvidia-smi

# %% [markdown]
# ## Step 2: Install Ollama

# %%
# !curl -fsSL https://ollama.com/install.sh | sh

# %% [markdown]
# ## Step 3: Start Ollama Server (Background)

# %%
import subprocess
import os

# Start Ollama in background
ollama_process = subprocess.Popen(['ollama', 'serve'], stdout=subprocess.PIPE, stderr=subprocess.PIPE)
print("Ollama server started")

# %% [markdown]
# ## Step 4: Download qwen2.5-coder:32b (Most Advanced Model)
# This will take 10-15 minutes and use ~20-25GB of disk space

# %%
# !ollama pull qwen2.5-coder:32b

# %% [markdown]
# ## Step 5: Test the Model

# %%
# !ollama run qwen2.5-coder:32b

# %% [markdown]
# ## Alternative: Use via Python API
# If you want to integrate with your code:

# %%
import requests
import json

def query_ollama(prompt, model="qwen2.5-coder:32b"):
    url = "http://localhost:11434/api/generate"
    payload = {
        "model": model,
        "prompt": prompt,
        "stream": False
    }
    response = requests.post(url, json=payload)
    return response.json()

# Example usage
result = query_ollama("Write a Python function to calculate fibonacci numbers")
print(result.get('response', 'No response'))
